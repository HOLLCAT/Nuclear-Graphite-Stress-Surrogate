# %% [markdown]
# # Formal V11 Symbolic Regression: Iteration 3
#
# This notebook runs one complete frozen development rotation:
#
# 1. V10 signed staged residual symbolic search, using the Iteration-3
#    119 training cases and 595,000 stratified discovery rows;
# 2. V11 case-mean calibration and tail-aware localised symbolic search;
# 3. validation-only scalar gain selection, followed by one internal-test audit.
#
# Every complete validation and internal-test case is evaluated. The 50 final
# test case names are inventoried but their element files are not read. Each
# PySR stage is segmented and recoverable, so a rerun resumes completed work.

# %% [markdown]
# ## 1. Imports and package root

# %%
from pathlib import Path
import json
import sys

import pandas as pd

try:
    from IPython.display import display
except Exception:
    display = print


def resolve_package_root() -> Path:
    current = Path.cwd().resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "src" / "formal_v11_four_rotation.py").exists():
            return candidate
    raise FileNotFoundError("Could not locate the NotebookCT3 package root.")


PACKAGE_ROOT = resolve_package_root()
if str(PACKAGE_ROOT / "src") not in sys.path:
    sys.path.insert(0, str(PACKAGE_ROOT / "src"))

print("Package root:", PACKAGE_ROOT)
print("Python:", sys.executable)
# Out:
# Package root: /net/scratch/j96317yn/NotebookCT3
# Python: /net/scratch/j96317yn/NotebookCT3/.venv/bin/python

# %% [markdown]
# ## 2. Run or resume the locked rotation

# %%
from formal_v11_four_rotation import output_directory, run_formal_rotation

ITERATION = 3
RUN_FORMAL_ROTATION = True
OUTPUT_DIR = output_directory(PACKAGE_ROOT, ITERATION)

if RUN_FORMAL_ROTATION:
    RESULT = run_formal_rotation(PACKAGE_ROOT, ITERATION)
    display(pd.DataFrame([RESULT]))
else:
    RESULT = None
    print("Formal rotation skipped.")
# Out:
# [1/119] V10 signed-residual sample: case_01
# [2/119] V10 signed-residual sample: case_06
# [3/119] V10 signed-residual sample: case_10
# [4/119] V10 signed-residual sample: case_11
# [5/119] V10 signed-residual sample: case_12
# [6/119] V10 signed-residual sample: case_13
# [7/119] V10 signed-residual sample: case_14
# [8/119] V10 signed-residual sample: case_17
# [9/119] V10 signed-residual sample: case_18
# [10/119] V10 signed-residual sample: case_19
# [11/119] V10 signed-residual sample: case_20
# [12/119] V10 signed-residual sample: case_21
# [13/119] V10 signed-residual sample: case_27
# [14/119] V10 signed-residual sample: case_28
# [15/119] V10 signed-residual sample: case_29
# [16/119] V10 signed-residual sample: case_32
# [17/119] V10 signed-residual sample: case_34
# [18/119] V10 signed-residual sample: case_35
# [19/119] V10 signed-residual sample: case_40
# [20/119] V10 signed-residual sample: case_42
# [21/119] V10 signed-residual sample: case_43
# [22/119] V10 signed-residual sample: case_44
# [23/119] V10 signed-residual sample: case_45
# [24/119] V10 signed-residual sample: case_49
# [25/119] V10 signed-residual sample: case_51
# [26/119] V10 signed-residual sample: case_54
# [27/119] V10 signed-residual sample: case_56
# [28/119] V10 signed-residual sample: case_57
# [29/119] V10 signed-residual sample: case_58
# [30/119] V10 signed-residual sample: case_59
# [31/119] V10 signed-residual sample: case_60
# [32/119] V10 signed-residual sample: case_61
# [33/119] V10 signed-residual sample: case_62
# [34/119] V10 signed-residual sample: case_64
# [35/119] V10 signed-residual sample: case_66
# [36/119] V10 signed-residual sample: case_69
# [37/119] V10 signed-residual sample: case_71
# [38/119] V10 signed-residual sample: case_72
# [39/119] V10 signed-residual sample: case_73
# [40/119] V10 signed-residual sample: case_75
# [41/119] V10 signed-residual sample: case_77
# [42/119] V10 signed-residual sample: case_79
# [43/119] V10 signed-residual sample: case_81
# [44/119] V10 signed-residual sample: case_82
# [45/119] V10 signed-residual sample: case_83
# [46/119] V10 signed-residual sample: case_84
# [47/119] V10 signed-residual sample: case_85
# [48/119] V10 signed-residual sample: case_86
# [49/119] V10 signed-residual sample: case_87
# [50/119] V10 signed-residual sample: case_89
# [51/119] V10 signed-residual sample: case_91
# [52/119] V10 signed-residual sample: case_92
# [53/119] V10 signed-residual sample: case_93
# [54/119] V10 signed-residual sample: case_94
# [55/119] V10 signed-residual sample: case_96
# [56/119] V10 signed-residual sample: case_97
# [57/119] V10 signed-residual sample: case_98
# [58/119] V10 signed-residual sample: case_99
# [59/119] V10 signed-residual sample: case_100
# [60/119] V10 signed-residual sample: case_101
# [61/119] V10 signed-residual sample: case_102
# [62/119] V10 signed-residual sample: case_104
# [63/119] V10 signed-residual sample: case_105
# [64/119] V10 signed-residual sample: case_106
# [65/119] V10 signed-residual sample: case_107
# [66/119] V10 signed-residual sample: case_109
# [67/119] V10 signed-residual sample: case_110
# [68/119] V10 signed-residual sample: case_111
# [69/119] V10 signed-residual sample: case_114
# [70/119] V10 signed-residual sample: case_115
# [71/119] V10 signed-residual sample: case_118
# [72/119] V10 signed-residual sample: case_119
# [73/119] V10 signed-residual sample: case_120
# [74/119] V10 signed-residual sample: case_121
# [75/119] V10 signed-residual sample: case_122
# [76/119] V10 signed-residual sample: case_125
# [77/119] V10 signed-residual sample: case_127
# [78/119] V10 signed-residual sample: case_128
# [79/119] V10 signed-residual sample: case_129
# [80/119] V10 signed-residual sample: case_130
# [81/119] V10 signed-residual sample: case_136
# [82/119] V10 signed-residual sample: case_137
# [83/119] V10 signed-residual sample: case_141
# [84/119] V10 signed-residual sample: case_142
# [85/119] V10 signed-residual sample: case_143
# [86/119] V10 signed-residual sample: case_144
# [87/119] V10 signed-residual sample: case_145
# [88/119] V10 signed-residual sample: case_146
# [89/119] V10 signed-residual sample: case_147
# [90/119] V10 signed-residual sample: case_151
# [91/119] V10 signed-residual sample: case_153
# [92/119] V10 signed-residual sample: case_154
# [93/119] V10 signed-residual sample: case_155
# [94/119] V10 signed-residual sample: case_158
# [95/119] V10 signed-residual sample: case_159
# [96/119] V10 signed-residual sample: case_163
# [97/119] V10 signed-residual sample: case_164
# [98/119] V10 signed-residual sample: case_166
# [99/119] V10 signed-residual sample: case_169
# [100/119] V10 signed-residual sample: case_170
# [101/119] V10 signed-residual sample: case_171
# [102/119] V10 signed-residual sample: case_173
# [103/119] V10 signed-residual sample: case_175
# [104/119] V10 signed-residual sample: case_176
# [105/119] V10 signed-residual sample: case_179
# [106/119] V10 signed-residual sample: case_180
# [107/119] V10 signed-residual sample: case_183
# [108/119] V10 signed-residual sample: case_184
# [109/119] V10 signed-residual sample: case_185
# [110/119] V10 signed-residual sample: case_186
# [111/119] V10 signed-residual sample: case_187
# [112/119] V10 signed-residual sample: case_188
# [113/119] V10 signed-residual sample: case_193
# [114/119] V10 signed-residual sample: case_194
# [115/119] V10 signed-residual sample: case_195
# [116/119] V10 signed-residual sample: case_196
# [117/119] V10 signed-residual sample: case_197
# [118/119] V10 signed-residual sample: case_199
# [119/119] V10 signed-residual sample: case_200
# V10 geometry segment 1/5, attempt 1: fresh search
# V10 geometry segment 1, attempt 1: elapsed=0.0 min, inactive=0.0 min, checkpoint=False
# V10 geometry segment 1, attempt 1: elapsed=5.0 min, inactive=0.0 min, checkpoint=True
# V10 geometry segment 1: complete; planned cumulative 800/4000
# V10 geometry segment 2/5, attempt 1: resume
# V10 geometry segment 2, attempt 1: elapsed=0.0 min, inactive=0.0 min, checkpoint=True
# V10 geometry segment 2, attempt 1: elapsed=5.0 min, inactive=0.0 min, checkpoint=True
# V10 geometry segment 2: complete; planned cumulative 1600/4000
# V10 geometry segment 3/5, attempt 1: resume
# V10 geometry segment 3, attempt 1: elapsed=0.0 min, inactive=0.0 min, checkpoint=True
# V10 geometry segment 3, attempt 1: elapsed=5.0 min, inactive=0.0 min, checkpoint=True
# V10 geometry segment 3: complete; planned cumulative 2400/4000
# V10 geometry segment 4/5, attempt 1: resume
# V10 geometry segment 4, attempt 1: elapsed=0.0 min, inactive=0.0 min, checkpoint=True
# V10 geometry segment 4, attempt 1: elapsed=5.0 min, inactive=0.0 min, checkpoint=True
# V10 geometry segment 4: complete; planned cumulative 3200/4000
# V10 geometry segment 5/5, attempt 1: resume
# V10 geometry segment 5, attempt 1: elapsed=0.0 min, inactive=0.0 min, checkpoint=True
# V10 geometry segment 5, attempt 1: elapsed=5.0 min, inactive=0.0 min, checkpoint=True
# V10 geometry segment 5, attempt 1: elapsed=10.0 min, inactive=0.0 min, checkpoint=True
# V10 geometry segment 5: complete; planned cumulative 4000/4000
# [1/15] validation complete-case V10 geometry: case_15
# [2/15] validation complete-case V10 geometry: case_24
# [3/15] validation complete-case V10 geometry: case_36
# [4/15] validation complete-case V10 geometry: case_39
# [5/15] validation complete-case V10 geometry: case_63
# [6/15] validation complete-case V10 geometry: case_74
# [7/15] validation complete-case V10 geometry: case_78
# [8/15] validation complete-case V10 geometry: case_117
# [9/15] validation complete-case V10 geometry: case_124
# [10/15] validation complete-case V10 geometry: case_148
# [11/15] validation complete-case V10 geometry: case_150
# [12/15] validation complete-case V10 geometry: case_156
# [13/15] validation complete-case V10 geometry: case_165
# [14/15] validation complete-case V10 geometry: case_181
# [15/15] validation complete-case V10 geometry: case_190
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[False False False  True  True  True  True  True  True  True  True  True
#   True  True  True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[False False False False  True  True  True  True  True  True  True  True
#   True  True  True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[False False False  True  True False False  True  True  True  True  True
#   True  True  True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[False False False False False False False False False False False False
#  False False False False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[False False False False False False False False False False False False
#  False False False False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[False False False False  True  True  True  True  True  True  True  True
#   True  True  True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[False False False False False False False False False False False False
#  False False False False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# V10 physical segment 1/5, attempt 1: fresh search
# V10 physical segment 1, attempt 1: elapsed=0.0 min, inactive=0.0 min, checkpoint=False
# V10 physical segment 1, attempt 1: elapsed=5.0 min, inactive=0.0 min, checkpoint=True
# V10 physical segment 1: complete; planned cumulative 800/4000
# V10 physical segment 2/5, attempt 1: resume
# V10 physical segment 2, attempt 1: elapsed=0.0 min, inactive=0.0 min, checkpoint=True
# V10 physical segment 2, attempt 1: elapsed=5.0 min, inactive=0.0 min, checkpoint=True
# V10 physical segment 2: complete; planned cumulative 1600/4000
# V10 physical segment 3/5, attempt 1: resume
# V10 physical segment 3, attempt 1: elapsed=0.0 min, inactive=0.0 min, checkpoint=True
# V10 physical segment 3, attempt 1: elapsed=5.0 min, inactive=0.0 min, checkpoint=True
# V10 physical segment 3: complete; planned cumulative 2400/4000
# V10 physical segment 4/5, attempt 1: resume
# V10 physical segment 4, attempt 1: elapsed=0.0 min, inactive=0.0 min, checkpoint=True
# V10 physical segment 4, attempt 1: elapsed=5.0 min, inactive=0.0 min, checkpoint=True
# V10 physical segment 4: complete; planned cumulative 3200/4000
# V10 physical segment 5/5, attempt 1: resume
# V10 physical segment 5, attempt 1: elapsed=0.0 min, inactive=0.0 min, checkpoint=True
# V10 physical segment 5, attempt 1: elapsed=5.0 min, inactive=0.0 min, checkpoint=True
# V10 physical segment 5: complete; planned cumulative 4000/4000
# [1/15] validation complete-case V10 physical: case_15
# [2/15] validation complete-case V10 physical: case_24
# [3/15] validation complete-case V10 physical: case_36
# [4/15] validation complete-case V10 physical: case_39
# [5/15] validation complete-case V10 physical: case_63
# [6/15] validation complete-case V10 physical: case_74
# [7/15] validation complete-case V10 physical: case_78
# [8/15] validation complete-case V10 physical: case_117
# [9/15] validation complete-case V10 physical: case_124
# [10/15] validation complete-case V10 physical: case_148
# [11/15] validation complete-case V10 physical: case_150
# [12/15] validation complete-case V10 physical: case_156
# [13/15] validation complete-case V10 physical: case_165
# [14/15] validation complete-case V10 physical: case_181
# [15/15] validation complete-case V10 physical: case_190
# [1/15] internal_test complete-case V10 physical: case_16
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True  True  True  True  True  True False False False False False False
#  False False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[False False False False False False False False False False False False
#  False False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[False False False False False False False False False False False False
#  False False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[False False False  True  True  True  True  True  True  True  True  True
#   True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/signed_staged_residual_symbolic.py:1310: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[False False False False False False False False False False False False
#  False False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   candidate_metrics.loc[valid.index, valid.columns] = valid
# [2/15] internal_test complete-case V10 physical: case_47
# [3/15] internal_test complete-case V10 physical: case_48
# [4/15] internal_test complete-case V10 physical: case_52
# [5/15] internal_test complete-case V10 physical: case_67
# [6/15] internal_test complete-case V10 physical: case_68
# [7/15] internal_test complete-case V10 physical: case_95
# [8/15] internal_test complete-case V10 physical: case_116
# [9/15] internal_test complete-case V10 physical: case_133
# [10/15] internal_test complete-case V10 physical: case_139
# [11/15] internal_test complete-case V10 physical: case_157
# [12/15] internal_test complete-case V10 physical: case_182
# [13/15] internal_test complete-case V10 physical: case_189
# [14/15] internal_test complete-case V10 physical: case_191
# [15/15] internal_test complete-case V10 physical: case_192
# V11 tail segment 1/5, attempt 1: fresh search
# V11 segment 1, attempt 1: elapsed=0.0 min, inactive=0.0 min, checkpoint=False
# V11 segment 1, attempt 1: elapsed=5.0 min, inactive=0.0 min, checkpoint=True
# V11 tail segment 1: complete; planned cumulative 800/4000
# V11 tail segment 2/5, attempt 1: resume
# V11 segment 2, attempt 1: elapsed=0.0 min, inactive=0.0 min, checkpoint=True
# V11 segment 2, attempt 1: elapsed=5.0 min, inactive=0.0 min, checkpoint=True
# V11 tail segment 2: complete; planned cumulative 1600/4000
# V11 tail segment 3/5, attempt 1: resume
# V11 segment 3, attempt 1: elapsed=0.0 min, inactive=0.0 min, checkpoint=True
# V11 segment 3, attempt 1: elapsed=5.0 min, inactive=0.0 min, checkpoint=True
# V11 segment 3, attempt 1: elapsed=10.0 min, inactive=0.0 min, checkpoint=True
# V11 tail segment 3: complete; planned cumulative 2400/4000
# V11 tail segment 4/5, attempt 1: resume
# V11 segment 4, attempt 1: elapsed=0.0 min, inactive=0.0 min, checkpoint=True
# V11 segment 4, attempt 1: elapsed=5.0 min, inactive=0.0 min, checkpoint=True
# V11 tail segment 4: complete; planned cumulative 3200/4000
# V11 tail segment 5/5, attempt 1: resume
# V11 segment 5, attempt 1: elapsed=0.0 min, inactive=0.0 min, checkpoint=True
# V11 segment 5, attempt 1: elapsed=5.0 min, inactive=0.0 min, checkpoint=True
# V11 tail segment 5: complete; planned cumulative 4000/4000
# [1/15] validation complete-case V11: case_15
# [2/15] validation complete-case V11: case_24
# [3/15] validation complete-case V11: case_36
# [4/15] validation complete-case V11: case_39
# [5/15] validation complete-case V11: case_63
# [6/15] validation complete-case V11: case_74
# [7/15] validation complete-case V11: case_78
# [8/15] validation complete-case V11: case_117
# [9/15] validation complete-case V11: case_124
# [10/15] validation complete-case V11: case_148
# [11/15] validation complete-case V11: case_150
# [12/15] validation complete-case V11: case_156
# [13/15] validation complete-case V11: case_165
# [14/15] validation complete-case V11: case_181
# [15/15] validation complete-case V11: case_190
# [1/15] internal_test complete-case V11: case_16
# /net/scratch/j96317yn/NotebookCT3/src/v11_tail_aware_localised_symbolic.py:1173: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True  True  True  True  True  True  True  True  True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/v11_tail_aware_localised_symbolic.py:1173: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True  True  True  True  True  True  True  True  True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/v11_tail_aware_localised_symbolic.py:1173: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True False False False False  True False False  True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/v11_tail_aware_localised_symbolic.py:1173: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True False False False False  True False False  True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/v11_tail_aware_localised_symbolic.py:1173: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True  True  True  True  True  True  True  True  True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/v11_tail_aware_localised_symbolic.py:1173: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[False False False  True  True  True False  True False  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/v11_tail_aware_localised_symbolic.py:1173: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[False False False False False False False False False False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/v11_tail_aware_localised_symbolic.py:1173: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[False False False False False False False False False False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/v11_tail_aware_localised_symbolic.py:1173: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ True  True  True  True  True  True  True  True  True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   metrics.loc[valid.index, valid.columns] = valid
# /net/scratch/j96317yn/NotebookCT3/src/v11_tail_aware_localised_symbolic.py:1173: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[False False False False False False False False False False]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   metrics.loc[valid.index, valid.columns] = valid
# [2/15] internal_test complete-case V11: case_47
# [3/15] internal_test complete-case V11: case_48
# [4/15] internal_test complete-case V11: case_52
# [5/15] internal_test complete-case V11: case_67
# [6/15] internal_test complete-case V11: case_68
# [7/15] internal_test complete-case V11: case_95
# [8/15] internal_test complete-case V11: case_116
# [9/15] internal_test complete-case V11: case_133
# [10/15] internal_test complete-case V11: case_139
# [11/15] internal_test complete-case V11: case_157
# [12/15] internal_test complete-case V11: case_182
# [13/15] internal_test complete-case V11: case_189
# [14/15] internal_test complete-case V11: case_191
# [15/15] internal_test complete-case V11: case_192
# [1/15] validation: full-case gain audit for case_15
# [2/15] validation: full-case gain audit for case_24
# [3/15] validation: full-case gain audit for case_36
# [4/15] validation: full-case gain audit for case_39
# [5/15] validation: full-case gain audit for case_63
# [6/15] validation: full-case gain audit for case_74
# [7/15] validation: full-case gain audit for case_78
# [8/15] validation: full-case gain audit for case_117
# [9/15] validation: full-case gain audit for case_124
# [10/15] validation: full-case gain audit for case_148
# [11/15] validation: full-case gain audit for case_150
# [12/15] validation: full-case gain audit for case_156
# [13/15] validation: full-case gain audit for case_165
# [14/15] validation: full-case gain audit for case_181
# [15/15] validation: full-case gain audit for case_190
# [1/15] internal_test: full-case gain audit for case_16
# [2/15] internal_test: full-case gain audit for case_47
# [3/15] internal_test: full-case gain audit for case_48
# [4/15] internal_test: full-case gain audit for case_52
# [5/15] internal_test: full-case gain audit for case_67
# [6/15] internal_test: full-case gain audit for case_68
# [7/15] internal_test: full-case gain audit for case_95
# [8/15] internal_test: full-case gain audit for case_116
# [9/15] internal_test: full-case gain audit for case_133
# [10/15] internal_test: full-case gain audit for case_139
# [11/15] internal_test: full-case gain audit for case_157
# [12/15] internal_test: full-case gain audit for case_182
# [13/15] internal_test: full-case gain audit for case_189
# [14/15] internal_test: full-case gain audit for case_191
# [15/15] internal_test: full-case gain audit for case_192
#      status  iteration                              execution_mode  \
# 0  complete          3  fresh_rotation_specific_training_and_audit
#
#                                               method  selected_gain  \
# 0  v10_signed_staged_plus_v11_tail_plus_validatio...           0.95
#
#    v10_population_iterations  v11_population_iterations  train_cases  \
# 0                       8000                       4000          119
#
#    validation_cases  internal_test_cases  final_test_cases_read  \
# 0                15                   15                      0
#
#    elapsed_seconds                               v10_output_directory  \
# 0      8987.870358  /net/scratch/j96317yn/NotebookCT3/outputs/10_s...
#
#                                 v11_output_directory  \
# 0  /net/scratch/j96317yn/NotebookCT3/outputs/11_t...
#
#                                gain_output_directory
# 0  /net/scratch/j96317yn/NotebookCT3/outputs/12_v...

# %% [markdown]
# ## 3. Saved evidence

# %%
roots = {
    "pipeline": OUTPUT_DIR,
    "v10": PACKAGE_ROOT / "outputs/10_signed_staged_residual_symbolic_pilot/iteration_3",
    "v11": PACKAGE_ROOT / "outputs/11_tail_aware_localised_symbolic/iteration_3",
    "gain": PACKAGE_ROOT / "outputs/12_v11_gain_stability_audit/iteration_3",
}

artifacts = {
    "pipeline_completion": roots["pipeline"] / "pipeline_complete.json",
    "v10_completion": roots["v10"] / "pilot_complete.json",
    "v11_completion": roots["v11"] / "pilot_complete.json",
    "gain_completion": roots["gain"] / "audit_complete.json",
    "selected_gain": roots["gain"] / "selected_gain.json",
    "selected_formula": roots["gain"] / "selected_gain_formula.txt",
    "split_metrics": roots["gain"] / "selected_models_split_metrics.csv",
}
for name, artifact in artifacts.items():
    print(f"{name:22s} exists={artifact.exists()}  {artifact}")

if artifacts["split_metrics"].exists():
    display(pd.read_csv(artifacts["split_metrics"]))
if artifacts["selected_formula"].exists():
    print("\n" + artifacts["selected_formula"].read_text(encoding="utf-8"))
# Out:
# pipeline_completion    exists=True  /net/scratch/j96317yn/NotebookCT3/outputs/17_v11_four_rotation_formal/iteration_3/pipeline_complete.json
# v10_completion         exists=True  /net/scratch/j96317yn/NotebookCT3/outputs/10_signed_staged_residual_symbolic_pilot/iteration_3/pilot_complete.json
# v11_completion         exists=True  /net/scratch/j96317yn/NotebookCT3/outputs/11_tail_aware_localised_symbolic/iteration_3/pilot_complete.json
# gain_completion        exists=True  /net/scratch/j96317yn/NotebookCT3/outputs/12_v11_gain_stability_audit/iteration_3/audit_complete.json
# selected_gain          exists=True  /net/scratch/j96317yn/NotebookCT3/outputs/12_v11_gain_stability_audit/iteration_3/selected_gain.json
# selected_formula       exists=True  /net/scratch/j96317yn/NotebookCT3/outputs/12_v11_gain_stability_audit/iteration_3/selected_gain_formula.txt
# split_metrics          exists=True  /net/scratch/j96317yn/NotebookCT3/outputs/12_v11_gain_stability_audit/iteration_3/selected_models_split_metrics.csv
#    iteration          split                       model  \
# 0          3  internal_test  v10_signed_staged_symbolic
# 1          3  internal_test       v11_current_gain_1_00
# 2          3  internal_test     v11_mean_calibrated_v10
# 3          3  internal_test      v11_selected_gain_0.95
# 4          3     validation  v10_signed_staged_symbolic
# 5          3     validation       v11_current_gain_1_00
# 6          3     validation     v11_mean_calibrated_v10
# 7          3     validation      v11_selected_gain_0.95
#
#           reporting_role  n_cases  n_elements_evaluated  micro_mae  \
# 0       parent_reference       15               6005400   1.456252
# 1            current_v11       15               6005400   1.496511
# 2  mean_calibration_only       15               6005400   1.443806
# 3    validation_selected       15               6005400   1.490362
# 4       parent_reference       15               6005400   1.405624
# 5            current_v11       15               6005400   1.417153
# 6  mean_calibration_only       15               6005400   1.356724
# 7    validation_selected       15               6005400   1.410671
#
#    micro_rmse  micro_r2  macro_mae  ...  mean_top5_actual_rmse  \
# 0    2.056288  0.489611   1.456252  ...               3.729184
# 1    2.015662  0.509579   1.496511  ...               3.748575
# 2    1.991453  0.521289   1.443806  ...               4.164634
# 3    2.009450  0.512597   1.490362  ...               3.763381
# 4    1.963978  0.450249   1.405624  ...               3.226731
# 5    1.890458  0.490638   1.417153  ...               3.333384
# 6    1.852126  0.511085   1.356724  ...               3.619845
# 7    1.883393  0.494438   1.410671  ...               3.341447
#
#    mean_top5_actual_bias  mean_p95_relative_error  \
# 0              -2.345796                 0.046365
# 1              -2.448753                 0.030538
# 2              -2.998773                 0.036077
# 3              -2.476254                 0.029222
# 4              -1.682084                 0.061336
# 5              -1.963373                 0.045478
# 6              -2.365289                 0.047247
# 7              -1.983469                 0.044757
#
#    mean_p95_underprediction_fraction  mean_p99_relative_error  \
# 0                           0.001655                 0.146529
# 1                           0.005790                 0.162384
# 2                           0.032972                 0.190437
# 3                           0.006416                 0.165098
# 4                           0.001048                 0.102621
# 5                           0.011504                 0.131918
# 6                           0.036525                 0.155860
# 7                           0.012570                 0.134509
#
#    mean_p99_underprediction_fraction  mean_top5pct_hotspot_overlap  \
# 0                           0.145379                      0.457102
# 1                           0.162384                      0.489829
# 2                           0.190437                      0.457102
# 3                           0.165098                      0.489629
# 4                           0.102621                      0.507593
# 5                           0.131918                      0.525883
# 6                           0.155860                      0.507593
# 7                           0.134509                      0.526426
#
#    mean_top1pct_hotspot_overlap  mean_top1_recall_in_predicted_top5  \
# 0                      0.452364                            0.820130
# 1                      0.496387                            0.850117
# 2                      0.452364                            0.820130
# 3                      0.495671                            0.849833
# 4                      0.458325                            0.836047
# 5                      0.490842                            0.864602
# 6                      0.458325                            0.836047
# 7                      0.490776                            0.864669
#
#    max_prediction_abs_max_ratio
# 0                      0.933946
# 1                      0.926749
# 2                      0.904806
# 3                      0.925651
# 4                      1.029555
# 5                      1.023733
# 6                      0.998803
# 7                      1.022486
#
# [8 rows x 23 columns]
# CT3 frozen V11 gain-audited stress formula
# ===========================================
#
# Selected tail gain lambda = 0.95
#
# sigma_v10 = (-0.0116301024532845*temperature_mean + 0.0470427355318997*temperature_p95 - 3.16087946558646*weight_loss_rate_mean + 0.103449215368151*z_max - 0.870195660324862*Abs(4.60760803334225*fluence_rate_p95 - 20.3572633494299) - 100.195330145459) + exp(-1.47091131932291*rho_mean - 1011.416708227*theta_sin_std - 1.1690770556861*weight_loss_rate_mean + 0.904578545888617*z_mean + 9.23869712445276) * ((1.10317833861391*(0.55673575*(0.0509611749551904*rho - 9.32241465638866)*(0.0509611749551904*rho - 8.66867535638866) - 31.9731949759449*(theta_cos - 0.922666019258146)**2)*(Abs(0.0509611749551904*rho - 8.59575422638866) - 2.4201684) + 0.285739561816426) + (0.2037571042198979*(6.34896758686985*nearest_axial_boundary_fraction_proxy - 1.50273900081816)*(-7.28718952316989*nearest_radial_boundary_fraction_proxy + 4.82379391683032*rho_fraction_proxy + (6.34896758686985*nearest_axial_boundary_fraction_proxy - 1.50273900081816)*(4.979166764659604*nearest_radial_boundary_fraction_proxy - 0.7555397874783048) - 0.33238851694632) + 0.2037571042198979*tanh(0.953329938170801*z_within_case_z - 0.107660433093972) - 0.05430264797518295) + (-0.1031611420170622*(2.88495936431966*fluence_rate_mean - 10.3023995474472)*(7.28718952316989*nearest_radial_boundary_fraction_proxy - 2.40757030907997) + 0.0171984021271988))
# delta_mu_case = (1.087546506014469) + (-0.1972919681986823)*fluence_rate_mean + (-0.1307385628459594)*fluence_rate_p95 + (0.003179436386633568)*temperature_mean + (-0.005435986754984998)*temperature_p95 + (0.6020883350084407)*weight_loss_rate_mean + (6.902649612249388)*weight_loss_rate_std
# log_scale_v10 = -1.47091131932291*rho_mean - 1011.416708227*theta_sin_std - 1.1690770556861*weight_loss_rate_mean + 0.904578545888617*z_mean + 9.23869712445276
# tail_raw_v11 = -0.14658512288138305*(2.09089288702877*signed_angular_position_proxy + 0.137695505370236)*(-7.71320426068593*nearest_angular_boundary_fraction_proxy - (2.09089288702877*signed_angular_position_proxy + 0.137695505370236)*tanh(17.18609187709957*nearest_radial_boundary_fraction_proxy - 6.015348714070041) + 1.40911851509649) + 0.25775031369935591
# tail_centered_v11 = tail_raw_v11 - case_mean(tail_raw_v11)
#
# Combined expression
# sigma = ((-0.0116301024532845*temperature_mean + 0.0470427355318997*temperature_p95 - 3.16087946558646*weight_loss_rate_mean + 0.103449215368151*z_max - 0.870195660324862*Abs(4.60760803334225*fluence_rate_p95 - 20.3572633494299) - 100.195330145459) + exp(-1.47091131932291*rho_mean - 1011.416708227*theta_sin_std - 1.1690770556861*weight_loss_rate_mean + 0.904578545888617*z_mean + 9.23869712445276) * ((1.10317833861391*(0.55673575*(0.0509611749551904*rho - 9.32241465638866)*(0.0509611749551904*rho - 8.66867535638866) - 31.9731949759449*(theta_cos - 0.922666019258146)**2)*(Abs(0.0509611749551904*rho - 8.59575422638866) - 2.4201684) + 0.285739561816426) + (0.2037571042198979*(6.34896758686985*nearest_axial_boundary_fraction_proxy - 1.50273900081816)*(-7.28718952316989*nearest_radial_boundary_fraction_proxy + 4.82379391683032*rho_fraction_proxy + (6.34896758686985*nearest_axial_boundary_fraction_proxy - 1.50273900081816)*(4.979166764659604*nearest_radial_boundary_fraction_proxy - 0.7555397874783048) - 0.33238851694632) + 0.2037571042198979*tanh(0.953329938170801*z_within_case_z - 0.107660433093972) - 0.05430264797518295) + (-0.1031611420170622*(2.88495936431966*fluence_rate_mean - 10.3023995474472)*(7.28718952316989*nearest_radial_boundary_fraction_proxy - 2.40757030907997) + 0.0171984021271988))) + ((1.087546506014469) + (-0.1972919681986823)*fluence_rate_mean + (-0.1307385628459594)*fluence_rate_p95 + (0.003179436386633568)*temperature_mean + (-0.005435986754984998)*temperature_p95 + (0.6020883350084407)*weight_loss_rate_mean + (6.902649612249388)*weight_loss_rate_std) + (0.95) * exp(-1.47091131932291*rho_mean - 1011.416708227*theta_sin_std - 1.1690770556861*weight_loss_rate_mean + 0.904578545888617*z_mean + 9.23869712445276) * ((-0.14658512288138305*(2.09089288702877*signed_angular_position_proxy + 0.137695505370236)*(-7.71320426068593*nearest_angular_boundary_fraction_proxy - (2.09089288702877*signed_angular_position_proxy + 0.137695505370236)*tanh(17.18609187709957*nearest_radial_boundary_fraction_proxy - 6.015348714070041) + 1.40911851509649) + 0.25775031369935591) - case_mean(-0.14658512288138305*(2.09089288702877*signed_angular_position_proxy + 0.137695505370236)*(-7.71320426068593*nearest_angular_boundary_fraction_proxy - (2.09089288702877*signed_angular_position_proxy + 0.137695505370236)*tanh(17.18609187709957*nearest_radial_boundary_fraction_proxy - 6.015348714070041) + 1.40911851509649) + 0.25775031369935591))
#
# The selected lambda used only the 15 validation cases.
# The 15 internal-test cases were read only after lambda was frozen.
# The 50 final-test case element files were not read.
# Lambda values above 1.00 were diagnostic and were not selectable.

# %% [markdown]
# ## Interpretation
#
# This is a development-rotation result, not external validation. Formula
# coefficients are expected to change because the training cases change. The
# primary questions are whether the same hierarchical method remains useful,
# whether selected gain and feature families are reasonably stable, and whether
# validation improvements survive the one-time internal-test audit.
