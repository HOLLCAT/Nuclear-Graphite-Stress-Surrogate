# %% [markdown]
# # Aggregate Formal V11 Four-Rotation Stability
#
# Run this notebook only after Iterations 1-4 each have a formal completion
# record. It combines development validation/internal-test metrics, selected
# gains and exact formula records. It does not read any final-test element file.

# %%
from pathlib import Path
import json
import sys

import pandas as pd

try:
    from IPython.display import display
except Exception:
    display = print


def resolve_package_root() -> Path:
    current = Path.cwd().resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "src" / "formal_v11_four_rotation.py").exists():
            return candidate
    raise FileNotFoundError("Could not locate the NotebookCT3 package root.")


PACKAGE_ROOT = resolve_package_root()
if str(PACKAGE_ROOT / "src") not in sys.path:
    sys.path.insert(0, str(PACKAGE_ROOT / "src"))

print("Package root:", PACKAGE_ROOT)
print("Python:", sys.executable)
# Out:
# Package root: /net/scratch/j96317yn/NotebookCT3
# Python: /net/scratch/j96317yn/NotebookCT3/.venv/bin/python

# %%
from formal_v11_four_rotation import (
    aggregate_completed_rotations,
    output_directory,
)

RESULT = aggregate_completed_rotations(PACKAGE_ROOT)
SUMMARY_DIR = output_directory(PACKAGE_ROOT) / "four_rotation_summary"
print(json.dumps(RESULT, indent=2))
display(pd.read_csv(SUMMARY_DIR / "rotation_completion_summary.csv"))
display(pd.read_csv(SUMMARY_DIR / "selected_model_stability_summary.csv"))
# Out:
# {
#   "status": "complete",
#   "iterations": [
#     1,
#     2,
#     3,
#     4
#   ],
#   "completed_rotations": 4,
#   "selected_gains": [
#     0.9,
#     0.75,
#     0.95,
#     0.85
#   ],
#   "final_test_cases_read": 0,
#   "interpretation": "development_rotation_stability_not_external_validation",
#   "summary_directory": "/net/scratch/j96317yn/NotebookCT3/outputs/17_v11_four_rotation_formal/four_rotation_summary"
# }
#      status  iteration                                execution_mode  \
# 0  complete          1  registered_existing_reviewed_result_no_rerun
# 1  complete          2    fresh_rotation_specific_training_and_audit
# 2  complete          3    fresh_rotation_specific_training_and_audit
# 3  complete          4    fresh_rotation_specific_training_and_audit
#
#                                               method  selected_gain  \
# 0  v10_signed_staged_plus_v11_tail_plus_validatio...           0.90
# 1  v10_signed_staged_plus_v11_tail_plus_validatio...           0.75
# 2  v10_signed_staged_plus_v11_tail_plus_validatio...           0.95
# 3  v10_signed_staged_plus_v11_tail_plus_validatio...           0.85
#
#    v10_population_iterations  v11_population_iterations  train_cases  \
# 0                       8000                       4000          119
# 1                       8000                       4000          119
# 2                       8000                       4000          119
# 3                       8000                       4000          119
#
#    validation_cases  internal_test_cases  final_test_cases_read  \
# 0                15                   15                      0
# 1                15                   15                      0
# 2                15                   15                      0
# 3                15                   15                      0
#
#                                 v13_role  \
# 0  non_deployed_tail_correction_research
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
#
#                                         formula_path  \
# 0  /net/scratch/j96317yn/NotebookCT3/outputs/12_v...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#               registered_at  elapsed_seconds  \
# 0  2026-08-20T14:24:51+0100              NaN
# 1                       NaN      9256.706527
# 2                       NaN      8987.870358
# 3                       NaN     11612.391598
#
#                                 v10_output_directory  \
# 0                                                NaN
# 1  /net/scratch/j96317yn/NotebookCT3/outputs/10_s...
# 2  /net/scratch/j96317yn/NotebookCT3/outputs/10_s...
# 3  /net/scratch/j96317yn/NotebookCT3/outputs/10_s...
#
#                                 v11_output_directory  \
# 0                                                NaN
# 1  /net/scratch/j96317yn/NotebookCT3/outputs/11_t...
# 2  /net/scratch/j96317yn/NotebookCT3/outputs/11_t...
# 3  /net/scratch/j96317yn/NotebookCT3/outputs/11_t...
#
#                                gain_output_directory
# 0                                                NaN
# 1  /net/scratch/j96317yn/NotebookCT3/outputs/12_v...
# 2  /net/scratch/j96317yn/NotebookCT3/outputs/12_v...
# 3  /net/scratch/j96317yn/NotebookCT3/outputs/12_v...
#            split  rotations  macro_rmse_mean  macro_rmse_std  macro_r2_mean  \
# 0  internal_test          4         1.813019        0.142536       0.547636
# 1     validation          4         1.766826        0.073877       0.530172
#
#    p95_relative_error_mean  p99_relative_error_mean  \
# 0                 0.038720                 0.167395
# 1                 0.050127                 0.163986
#
#    top1_hotspot_overlap_mean  top1_hotspot_overlap_min
# 0                   0.514615                  0.486330
# 1                   0.516900                  0.474542

# %% [markdown]
# ## Selection boundary
#
# The four rotations support method and structure stability analysis. They do
# not authorise choosing a formula with the final 50 cases. A later constant
# refit may use all 149 development cases only after a structure is frozen; the
# final 50 cases are then evaluated exactly once.
