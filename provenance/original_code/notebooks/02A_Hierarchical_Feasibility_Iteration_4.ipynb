# %% [markdown]
# # V5 Feasibility: Hierarchical Stress Decomposition (Iteration 4)
#
# ## TL;DR
#
# This diagnostic tests a specific explanation for the V4 symbolic-regression
# failure. A single pointwise formula may be trying to learn two different
# tasks at once:
#
# 1. the overall stress level and upper-tail amplitude of an FEM case; and
# 2. the normalised spatial stress shape inside that case.
#
# The notebook therefore compares a direct nonlinear control with two
# hierarchical reconstructions:
#
# \[
# \hat\sigma_{e,c}=\hat B_c+\hat A_c\hat S_{e,c},
# \]
#
# where \(B_c\) is case mean stress, \(A_c=\sigma_{95,c}-B_c\), and
# \(S_{e,c}\) is the normalised element-level shape.
#
# The **oracle hierarchy** uses the true validation-case \(A_c,B_c\) only
# to test shape learnability. It is not deployable. The **deployable
# hierarchy** predicts \(A_c,B_c\) exclusively from summaries of available
# input fields. The locked 50-case final test is never read.

# %% [markdown]
# ### Execution note
#
# Run this notebook independently and wait for it to finish before starting another iteration. The models evaluate complete FEM cases and parallel notebook runs would compete for memory. The final-test cases remain sealed.

# %% [markdown]
# ## Context & Methods
#
# ### Key assumptions
#
# - One complete FEM case remains the independent experimental unit.
# - The frozen iteration-4 split is used: 119 training, 15 validation
#   and 15 internal-test cases. This preserves the pre-registered case-level
#   split and similarity-group constraints used throughout CT3.
# - All validation and internal-test elements are evaluated. Training uses
#   the same deterministic 5,000-row-per-case tail-stratified design already
#   audited in V4, so this experiment is directly comparable and quick.
# - Exported post-deformation coordinates are treated as available inputs.
# - Mean and P95 stress are decomposition targets during training, not model
#   inputs. At deployment they are predicted from input-field summaries.
# - This is a feasibility diagnostic using nonlinear controls. It does not
#   produce or approve the final symbolic formula.
#
# ### Fair comparison
#
# The direct and shape models use the same model family, sampled rows,
# weights and predictor matrix. The only intentional difference is whether
# the target is raw stress or within-case normalised stress. This isolates
# the value of the decomposition itself.

# %% [markdown]
# ## 1. Setup

# %%
from pathlib import Path
import sys
import pandas as pd

CWD = Path.cwd().resolve()
if (CWD / "src" / "ct3_common.py").exists():
    PACKAGE_ROOT = CWD
elif CWD.name == "notebooks" and (CWD.parent / "src" / "ct3_common.py").exists():
    PACKAGE_ROOT = CWD.parent
elif (CWD / "NotebookCT3" / "src" / "ct3_common.py").exists():
    PACKAGE_ROOT = CWD / "NotebookCT3"
else:
    raise FileNotFoundError("Could not locate NotebookCT3 from the current directory")

sys.path.insert(0, str(PACKAGE_ROOT / "src"))
from hierarchical_feasibility import FeasibilityConfig, run_feasibility

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 260)

CONFIG = FeasibilityConfig(
    iteration=4,
    rows_per_case=5_000,
    hgb_max_iter=180,
    output_subdir="iteration_4_pilot",
    force_rebuild_sample=False,
)
print("Package root:", PACKAGE_ROOT)
print("Configuration:", CONFIG)
# Out:
# Package root: /Users/novwin/Documents/University/University of Manchester/毕设项目/Nuclear graphite/NotebookCT3
# Configuration: FeasibilityConfig(iteration=4, rows_per_case=5000, hgb_max_iter=180, output_subdir='iteration_4_pilot', force_rebuild_sample=False)

# %% [markdown]
# ## 2. Run the Diagnostic
#
# The run has four bounded stages: reuse/assemble the audited training
# sample, select a case-level amplitude model using validation cases, fit
# direct and normalised-shape controls, then evaluate every element in the
# validation and internal-test cases.

# %%
RESULTS = run_feasibility(PACKAGE_ROOT, CONFIG)
# Out:
# Hierarchical feasibility diagnostic
# Package root: /Users/novwin/Documents/University/University of Manchester/毕设项目/Nuclear graphite/NotebookCT3
# Output directory: /Users/novwin/Documents/University/University of Manchester/毕设项目/Nuclear graphite/NotebookCT3/outputs/05_hierarchical_feasibility_v5/iteration_4_pilot
# Iteration 4: train=119, validation=15, internal_test=15; final test unread=50
# [1/119] Assemble training sample: case_01
# [2/119] Assemble training sample: case_06
# [3/119] Assemble training sample: case_10
# [4/119] Assemble training sample: case_12
# [5/119] Assemble training sample: case_13
# [6/119] Assemble training sample: case_14
# [7/119] Assemble training sample: case_15
# [8/119] Assemble training sample: case_16
# [9/119] Assemble training sample: case_18
# [10/119] Assemble training sample: case_19
# [11/119] Assemble training sample: case_20
# [12/119] Assemble training sample: case_21
# [13/119] Assemble training sample: case_24
# [14/119] Assemble training sample: case_27
# [15/119] Assemble training sample: case_28
# [16/119] Assemble training sample: case_29
# [17/119] Assemble training sample: case_32
# [18/119] Assemble training sample: case_34
# [19/119] Assemble training sample: case_35
# [20/119] Assemble training sample: case_36
# [21/119] Assemble training sample: case_39
# [22/119] Assemble training sample: case_40
# [23/119] Assemble training sample: case_42
# [24/119] Assemble training sample: case_43
# [25/119] Assemble training sample: case_45
# [26/119] Assemble training sample: case_47
# [27/119] Assemble training sample: case_48
# [28/119] Assemble training sample: case_49
# [29/119] Assemble training sample: case_51
# [30/119] Assemble training sample: case_52
# [31/119] Assemble training sample: case_54
# [32/119] Assemble training sample: case_56
# [33/119] Assemble training sample: case_57
# [34/119] Assemble training sample: case_58
# [35/119] Assemble training sample: case_59
# [36/119] Assemble training sample: case_60
# [37/119] Assemble training sample: case_62
# [38/119] Assemble training sample: case_63
# [39/119] Assemble training sample: case_64
# [40/119] Assemble training sample: case_66
# [41/119] Assemble training sample: case_67
# [42/119] Assemble training sample: case_68
# [43/119] Assemble training sample: case_71
# [44/119] Assemble training sample: case_72
# [45/119] Assemble training sample: case_73
# [46/119] Assemble training sample: case_74
# [47/119] Assemble training sample: case_75
# [48/119] Assemble training sample: case_77
# [49/119] Assemble training sample: case_81
# [50/119] Assemble training sample: case_82
# [51/119] Assemble training sample: case_83
# [52/119] Assemble training sample: case_84
# [53/119] Assemble training sample: case_85
# [54/119] Assemble training sample: case_86
# [55/119] Assemble training sample: case_87
# [56/119] Assemble training sample: case_92
# [57/119] Assemble training sample: case_93
# [58/119] Assemble training sample: case_94
# [59/119] Assemble training sample: case_95
# [60/119] Assemble training sample: case_96
# [61/119] Assemble training sample: case_97
# [62/119] Assemble training sample: case_98
# [63/119] Assemble training sample: case_100
# [64/119] Assemble training sample: case_101
# [65/119] Assemble training sample: case_102
# [66/119] Assemble training sample: case_104
# [67/119] Assemble training sample: case_105
# [68/119] Assemble training sample: case_106
# [69/119] Assemble training sample: case_110
# [70/119] Assemble training sample: case_111
# [71/119] Assemble training sample: case_114
# [72/119] Assemble training sample: case_115
# [73/119] Assemble training sample: case_116
# [74/119] Assemble training sample: case_117
# [75/119] Assemble training sample: case_119
# [76/119] Assemble training sample: case_120
# [77/119] Assemble training sample: case_121
# [78/119] Assemble training sample: case_122
# [79/119] Assemble training sample: case_125
# [80/119] Assemble training sample: case_127
# [81/119] Assemble training sample: case_128
# [82/119] Assemble training sample: case_129
# [83/119] Assemble training sample: case_130
# [84/119] Assemble training sample: case_136
# [85/119] Assemble training sample: case_137
# [86/119] Assemble training sample: case_141
# [87/119] Assemble training sample: case_142
# [88/119] Assemble training sample: case_143
# [89/119] Assemble training sample: case_144
# [90/119] Assemble training sample: case_145
# [91/119] Assemble training sample: case_146
# [92/119] Assemble training sample: case_147
# [93/119] Assemble training sample: case_148
# [94/119] Assemble training sample: case_150
# [95/119] Assemble training sample: case_151
# [96/119] Assemble training sample: case_153
# [97/119] Assemble training sample: case_155
# [98/119] Assemble training sample: case_157
# [99/119] Assemble training sample: case_158
# [100/119] Assemble training sample: case_159
# [101/119] Assemble training sample: case_164
# [102/119] Assemble training sample: case_165
# [103/119] Assemble training sample: case_169
# [104/119] Assemble training sample: case_170
# [105/119] Assemble training sample: case_171
# [106/119] Assemble training sample: case_173
# [107/119] Assemble training sample: case_175
# [108/119] Assemble training sample: case_176
# [109/119] Assemble training sample: case_179
# [110/119] Assemble training sample: case_181
# [111/119] Assemble training sample: case_182
# [112/119] Assemble training sample: case_184
# [113/119] Assemble training sample: case_187
# [114/119] Assemble training sample: case_188
# [115/119] Assemble training sample: case_193
# [116/119] Assemble training sample: case_194
# [117/119] Assemble training sample: case_195
# [118/119] Assemble training sample: case_196
# [119/119] Assemble training sample: case_197
# [1/30] Full-case evaluation: validation / case_11
# [2/30] Full-case evaluation: validation / case_17
# [3/30] Full-case evaluation: validation / case_44
# [4/30] Full-case evaluation: validation / case_61
# [5/30] Full-case evaluation: validation / case_69
# [6/30] Full-case evaluation: validation / case_78
# [7/30] Full-case evaluation: validation / case_91
# [8/30] Full-case evaluation: validation / case_107
# [9/30] Full-case evaluation: validation / case_109
# [10/30] Full-case evaluation: validation / case_139
# [11/30] Full-case evaluation: validation / case_166
# [12/30] Full-case evaluation: validation / case_183
# [13/30] Full-case evaluation: validation / case_191
# [14/30] Full-case evaluation: validation / case_192
# [15/30] Full-case evaluation: validation / case_199
# [16/30] Full-case evaluation: internal_test / case_79
# [17/30] Full-case evaluation: internal_test / case_89
# [18/30] Full-case evaluation: internal_test / case_99
# [19/30] Full-case evaluation: internal_test / case_118
# [20/30] Full-case evaluation: internal_test / case_124
# [21/30] Full-case evaluation: internal_test / case_133
# [22/30] Full-case evaluation: internal_test / case_154
# [23/30] Full-case evaluation: internal_test / case_156
# [24/30] Full-case evaluation: internal_test / case_163
# [25/30] Full-case evaluation: internal_test / case_180
# [26/30] Full-case evaluation: internal_test / case_185
# [27/30] Full-case evaluation: internal_test / case_186
# [28/30] Full-case evaluation: internal_test / case_189
# [29/30] Full-case evaluation: internal_test / case_190
# [30/30] Full-case evaluation: internal_test / case_200
#
# Split metrics:
#  iteration         split                   model  n_cases  n_elements_evaluated  micro_mae  micro_rmse  micro_r2  macro_mae  macro_rmse  macro_r2  worst_case_rmse  mean_top5_actual_rmse  mean_top5_actual_bias  mean_p95_relative_error  mean_p95_underprediction_fraction  mean_p99_relative_error  mean_p99_underprediction_fraction  mean_top5pct_hotspot_overlap  mean_top1pct_hotspot_overlap  mean_top1_recall_in_predicted_top5  max_prediction_abs_max_ratio  evaluation_seconds_total
#          4 internal_test deployable_hierarchical       15               6005400   0.356543    0.530319  0.959570   0.356543    0.515294  0.958458         0.879351               0.928429              -0.194516                 0.021000                           0.010530                 0.031308                           0.020913                      0.877360                      0.890776                            0.999967                      1.071347                140.959365
#          4 internal_test  direct_context_control       15               6005400   0.410702    0.587574  0.950368   0.410702    0.570791  0.947954         0.942237               1.021619              -0.273304                 0.030850                           0.014710                 0.035677                           0.026755                      0.864792                      0.880803                            0.999917                      1.080099                140.959365
#          4 internal_test     oracle_hierarchical       15               6005400   0.350641    0.519392  0.961219   0.350641    0.506771  0.959969         0.858662               0.874241              -0.128365                 0.011120                           0.002261                 0.019083                           0.010973                      0.877360                      0.890776                            0.999967                      1.043396                140.959365
#          4    validation deployable_hierarchical       15               6005400   0.392288    0.559979  0.963444   0.392288    0.553838  0.960223         0.708172               0.973899              -0.192873                 0.025448                           0.012098                 0.027755                           0.016524                      0.873257                      0.901166                            0.999983                      1.072916                140.959365
#          4    validation  direct_context_control       15               6005400   0.431892    0.608929  0.956774   0.431892    0.599271  0.953206         0.818628               1.101953              -0.463728                 0.025624                           0.017522                 0.037301                           0.036706                      0.865767                      0.886680                            0.999983                      1.026840                140.959365
#          4    validation     oracle_hierarchical       15               6005400   0.365744    0.540589  0.965932   0.365744    0.532565  0.964138         0.691951               0.921000              -0.217003                 0.007917                           0.003396                 0.009423                           0.009072                      0.873257                      0.901166                            0.999983                      1.008554                140.959365
#
# Feasibility decision:
#         split  oracle_macro_rmse_ratio_to_direct  deployable_macro_rmse_ratio_to_direct  oracle_p95_error_ratio_to_direct  deployable_p95_error_ratio_to_direct  oracle_p99_error_ratio_to_direct  deployable_p99_error_ratio_to_direct  oracle_shape_supported  deployable_hierarchy_supported
# internal_test                           0.887839                               0.902772                          0.360444                              0.680724                          0.534884                              0.877553                    True                            True
#    validation                           0.888689                               0.924186                          0.308970                              0.993142                          0.252621                              0.744071                    True                            True
#
# Saved outputs to: /Users/novwin/Documents/University/University of Manchester/毕设项目/Nuclear graphite/NotebookCT3/outputs/05_hierarchical_feasibility_v5/iteration_4_pilot

# %% [markdown]
# ## 3. Results

# %%
display(RESULTS["case_model_metrics"].sort_values(
    ["split", "selection_score", "mean_p95_relative_error"]
))
display(RESULTS["split_metrics"].sort_values(["split", "model"]))
display(RESULTS["decision_table"])
# Out:
#    iteration                  context_design  case_model          split  n_cases  offset_rmse  log_scale_rmse  mean_scale_relative_error  mean_p95_relative_error  p95_spearman  fit_seconds  selection_score
# 5          4  physical_plus_geometry_context     RidgeCV  internal_test       15     0.118760        0.038688                   0.032759                 0.022071      0.978571     0.002582         0.344635
# 7          4  physical_plus_geometry_context  ExtraTrees  internal_test       15     0.318821        0.045285                   0.031018                 0.029907      0.957143     0.182335         0.396934
# 1          4                physical_context     RidgeCV  internal_test       15     0.181262        0.075107                   0.064572                 0.040836      0.903571     0.006338         0.414861
# 3          4                physical_context  ExtraTrees  internal_test       15     0.264633        0.060252                   0.049877                 0.035857      0.942857     0.244145         0.501477
# 4          4  physical_plus_geometry_context     RidgeCV     validation       15     0.134484        0.046990                   0.037087                 0.024786      0.975000     0.002582         0.344635
# 6          4  physical_plus_geometry_context  ExtraTrees     validation       15     0.226178        0.036603                   0.029575                 0.027824      0.946429     0.182335         0.396934
# 0          4                physical_context     RidgeCV     validation       15     0.159461        0.057161                   0.051715                 0.023111      0.967857     0.006338         0.414861
# 2          4                physical_context  ExtraTrees     validation       15     0.244318        0.056424                   0.049147                 0.043061      0.985714     0.244145         0.501477
#    iteration          split                    model  n_cases  n_elements_evaluated  micro_mae  micro_rmse  micro_r2  macro_mae  macro_rmse  macro_r2  worst_case_rmse  mean_top5_actual_rmse  mean_top5_actual_bias  mean_p95_relative_error  \
# 0          4  internal_test  deployable_hierarchical       15               6005400   0.356543    0.530319  0.959570   0.356543    0.515294  0.958458         0.879351               0.928429              -0.194516                 0.021000
# 1          4  internal_test   direct_context_control       15               6005400   0.410702    0.587574  0.950368   0.410702    0.570791  0.947954         0.942237               1.021619              -0.273304                 0.030850
# 2          4  internal_test      oracle_hierarchical       15               6005400   0.350641    0.519392  0.961219   0.350641    0.506771  0.959969         0.858662               0.874241              -0.128365                 0.011120
# 3          4     validation  deployable_hierarchical       15               6005400   0.392288    0.559979  0.963444   0.392288    0.553838  0.960223         0.708172               0.973899              -0.192873                 0.025448
# 4          4     validation   direct_context_control       15               6005400   0.431892    0.608929  0.956774   0.431892    0.599271  0.953206         0.818628               1.101953              -0.463728                 0.025624
# 5          4     validation      oracle_hierarchical       15               6005400   0.365744    0.540589  0.965932   0.365744    0.532565  0.964138         0.691951               0.921000              -0.217003                 0.007917
#
#    mean_p95_underprediction_fraction  mean_p99_relative_error  mean_p99_underprediction_fraction  mean_top5pct_hotspot_overlap  mean_top1pct_hotspot_overlap  mean_top1_recall_in_predicted_top5  max_prediction_abs_max_ratio  evaluation_seconds_total
# 0                           0.010530                 0.031308                           0.020913                      0.877360                      0.890776                            0.999967                      1.071347                140.959365
# 1                           0.014710                 0.035677                           0.026755                      0.864792                      0.880803                            0.999917                      1.080099                140.959365
# 2                           0.002261                 0.019083                           0.010973                      0.877360                      0.890776                            0.999967                      1.043396                140.959365
# 3                           0.012098                 0.027755                           0.016524                      0.873257                      0.901166                            0.999983                      1.072916                140.959365
# 4                           0.017522                 0.037301                           0.036706                      0.865767                      0.886680                            0.999983                      1.026840                140.959365
# 5                           0.003396                 0.009423                           0.009072                      0.873257                      0.901166                            0.999983                      1.008554                140.959365
#            split  oracle_macro_rmse_ratio_to_direct  deployable_macro_rmse_ratio_to_direct  oracle_p95_error_ratio_to_direct  deployable_p95_error_ratio_to_direct  oracle_p99_error_ratio_to_direct  deployable_p99_error_ratio_to_direct  \
# 0  internal_test                           0.887839                               0.902772                          0.360444                              0.680724                          0.534884                              0.877553
# 1     validation                           0.888689                               0.924186                          0.308970                              0.993142                          0.252621                              0.744071
#
#    oracle_shape_supported  deployable_hierarchy_supported
# 0                    True                            True
# 1                    True                            True

# %%
from IPython.display import Image, display as show

OUTPUT_DIR = Path(RESULTS["run_summary"]["output_directory"])
for figure_name in [
    "hierarchical_method_comparison.png",
    "validation_p95_adaptation.png",
    "case_amplitude_prediction.png",
]:
    show(Image(filename=str(OUTPUT_DIR / figure_name)))

# %% [markdown]
# ## Takeaways and Decision Rule
#
# Interpret the three methods separately:
#
# - If the **oracle hierarchy** is clearly better than the direct control,
#   normalised shape is learnable and decomposition is structurally useful.
# - If oracle is good but the **deployable hierarchy** is poor, the main
#   bottleneck is predicting case amplitude/offset from input summaries.
# - If both hierarchical methods are comparable to or better than direct on
#   validation and internal test, a two-stage symbolic-regression V5 is
#   justified.
# - If oracle is materially worse than direct, do not spend another long
#   PySR run on this hierarchy. Revisit spatial representation or the target
#   definition first.
#
# The automated 5% comparison flags are screening aids, not proof. The
# final decision must also inspect P95/P99 error, underprediction, hotspot
# overlap, case ordering and consistency between validation and internal
# test. The final 50 cases remain sealed regardless of this result.
